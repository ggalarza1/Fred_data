# %% [markdown]
# <a href="https://colab.research.google.com/github/ggalarza1/Fred_data/blob/main/US_Fred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install fredapi

# %% [markdown]
# Using the Fred API, we are going to fetch the data from the US GDP.
#
# GDP = C + I + G + (X - M)
#
# C = Consumer Spending
# I = Investment
# G = Government Spending
# (X - M) = Net exports, which is exports minus imports

# %%
from fredapi import Fred
fred = Fred(api_key = 'ENTER YOUR KEY HERE')

#You need to insert the api key above. Once you do that, you can start using the API.

data = fred.get_series_latest_release('GDP')
data.tail()
# Out:
# 2023-07-01    27967.697
# 2023-10-01    28296.967
# 2024-01-01    28624.069
# 2024-04-01    29016.714
# 2024-07-01    29354.321
# dtype: float64

# %%
import matplotlib.pyplot as plt

plt.plot(data)
plt.show()

# %%
# Graphing the historical data
fig, ax = plt.subplots()

ax.plot(data.index, data, label='GDP')

# Adding the labels to the data
ax.set_xlabel('Year')
ax.set_ylabel('Value ($)')
ax.set_title(label= 'GDP', loc='center')
ax.legend()

# %%
#Exploring the Exports Data
data = fred.search_by_category(category_id=16)
data.tail()
# Out:
#                       id realtime_start realtime_end  \
# series id
# ITXMARM133S  ITXMARM133S     2024-12-19   2024-12-19
# ITXOBSM133S  ITXOBSM133S     2024-12-19   2024-12-19
# ITXTAEM133S  ITXTAEM133S     2024-12-19   2024-12-19
# ITXTCIM133S  ITXTCIM133S     2024-12-19   2024-12-19
# ITXTRAM133S  ITXTRAM133S     2024-12-19   2024-12-19
#
#                                                          title  \
# series id
# ITXMARM133S  U.S. Exports of Services: Maintenance and Repa...
# ITXOBSM133S  U.S. Exports of Services: Other Business Services
# ITXTAEM133S  U.S. Exports of Services: Travel (for All Purp...
# ITXTCIM133S  U.S. Exports of Services: Telecommunications, ...
# ITXTRAM133S                U.S. Exports of Services: Transport
#
#             observation_start observation_end frequency frequency_short  \
# series id
# ITXMARM133S        1999-01-01      2024-10-01   Monthly               M
# ITXOBSM133S        1999-01-01      2024-10-01   Monthly               M
# ...

# %%
#Exploring the Exports Data by category id and then filter by title
data = fred.search_by_category(category_id=16)
data = data[data['title'] == "U.S. Exports of Services: Transport"]  # Filter by title
data.tail()
# Out:
#                       id realtime_start realtime_end  \
# series id
# ITXTRAM133S  ITXTRAM133S     2024-12-19   2024-12-19
#
#                                            title observation_start  \
# series id
# ITXTRAM133S  U.S. Exports of Services: Transport        1999-01-01
#
#             observation_end frequency frequency_short                units  \
# series id
# ITXTRAM133S      2024-10-01   Monthly               M  Millions of Dollars
#
#             units_short  seasonal_adjustment seasonal_adjustment_short  \
# series id
# ITXTRAM133S   Mil. of $  Seasonally Adjusted                        SA
#
#                           last_updated popularity  \
# series id
# ITXTRAM133S  2024-12-05 07:51:09-06:00          2
#
#                                                          notes
# series id
# ITXTRAM133S  Further information related to the internation...

# %%
#You must specify the series ID of the data set you are fetching
data = fred.get_series('ITXTRAM133S')

#Graphing the data
plt.plot(data.index, data.values)
plt.xlabel('Year')
plt.ylabel('Value (Millions $)')
plt.title('U.S. Exports of Services: Transport')
plt.grid(True)
plt.show()

# %%
#Exploring Imports Data
data = fred.search_by_category(category_id=17)
data.tail()
# Out:
#                       id realtime_start realtime_end  \
# series id
# ITMMARM133S  ITMMARM133S     2024-12-19   2024-12-19
# ITMOBSM133S  ITMOBSM133S     2024-12-19   2024-12-19
# ITMTAEM133S  ITMTAEM133S     2024-12-19   2024-12-19
# ITMTCIM133S  ITMTCIM133S     2024-12-19   2024-12-19
# ITMTRAM133S  ITMTRAM133S     2024-12-19   2024-12-19
#
#                                                          title  \
# series id
# ITMMARM133S  U.S. Imports of Services: Maintenance and Repa...
# ITMOBSM133S  U.S. Imports of Services: Other Business Services
# ITMTAEM133S  U.S. Imports of Services: Travel (for All Purp...
# ITMTCIM133S  U.S. Imports of Services: Telecommunications, ...
# ITMTRAM133S                U.S. Imports of Services: Transport
#
#             observation_start observation_end frequency frequency_short  \
# series id
# ITMMARM133S        1999-01-01      2024-10-01   Monthly               M
# ITMOBSM133S        1999-01-01      2024-10-01   Monthly               M
# ...

# %%
#You must specify the series ID of the data set you are fetching
data = fred.get_series('ITMTRAM133S')

#Graphing the data
plt.plot(data.index, data.values)
plt.xlabel('Year')
plt.ylabel('Value (Millions $)')
plt.title('U.S. Imports of Services: Transport')
plt.grid(True)
plt.show()

# %%
#Exploring Income Payments & Receipts
data = fred.search_by_category(category_id=3000)
data.tail()
# Out:
#                                   id realtime_start realtime_end  \
# series id
# IEAXSIRA                    IEAXSIRA     2024-12-19   2024-12-19
# IEAXSIRN                    IEAXSIRN     2024-12-19   2024-12-19
# LA0000331A027NBEA  LA0000331A027NBEA     2024-12-19   2024-12-19
# LA0000341A027NBEA  LA0000341A027NBEA     2024-12-19   2024-12-19
# LA0000421A027NBEA  LA0000421A027NBEA     2024-12-19   2024-12-19
#
#                                                                title  \
# series id
# IEAXSIRA                Secondary income (current transfer) receipts
# IEAXSIRN                Secondary income (current transfer) receipts
# LA0000331A027NBEA  Secondary income receipts: Statistical differe...
# LA0000341A027NBEA  Secondary income receipts: Adjustment for U.S....
# LA0000421A027NBEA  Secondary income receipts, International Trans...
#
#                   observation_start observation_end  frequency  \
# series id
# ...

# %%
#fetching the name of the series
series_info = fred.get_series_info('LA0000421A027NBEA')
title = series_info['title']
print(title)
# Out:
# Secondary income receipts, International Transactions Accounts

# %%
#You must specify the series ID of the data set you are fetching
data = fred.get_series('LA0000421A027NBEA')

#Graphing the data
plt.plot(data.index, data.values)
plt.xlabel('Year')
plt.ylabel('Value (Billions $)')
plt.title('Secondary income receipts, International Transactions Accounts')
plt.grid(True)
plt.show()

# %%
#Exploring Trade Balance
data = fred.search_by_category(category_id=125)
data.tail()
# Out:
#                  id realtime_start realtime_end                        title  \
# series id
# IEABCSA     IEABCSA     2024-12-19   2024-12-19          Balance on services
# IEABCSI     IEABCSI     2024-12-19   2024-12-19  Balance on secondary income
# IEABCSIA   IEABCSIA     2024-12-19   2024-12-19  Balance on secondary income
# IEABCSIN   IEABCSIN     2024-12-19   2024-12-19  Balance on secondary income
# IEABCSN     IEABCSN     2024-12-19   2024-12-19          Balance on services
#
#           observation_start observation_end  frequency frequency_short  \
# series id
# IEABCSA          1999-01-01      2023-01-01     Annual               A
# IEABCSI          1999-01-01      2024-07-01  Quarterly               Q
# IEABCSIA         1999-01-01      2023-01-01     Annual               A
# IEABCSIN         1999-01-01      2024-07-01  Quarterly               Q
# IEABCSN          1999-01-01      2024-07-01  Quarterly               Q
#
# ...

# %%
#You must specify the series ID of the data set you are fetching
data = fred.get_series('IEABCSN')

#Graphing the data
plt.plot(data.index, data.values)
plt.xlabel('Year')
plt.ylabel('Value (Millions $)')
plt.title('Balance on services')
plt.grid(True)
plt.show()

# %%
#Exploring U.S. International Finance
data = fred.search_by_category(category_id=127)
data.tail()
# Out:
#                 id realtime_start realtime_end  \
# series id
# IEAIPIN    IEAIPIN     2024-12-19   2024-12-19
# IEASAD      IEASAD     2024-12-19   2024-12-19
# IEASD        IEASD     2024-12-19   2024-12-19
# IEASDA      IEASDA     2024-12-19   2024-12-19
# IEASDN      IEASDN     2024-12-19   2024-12-19
#
#                                                        title  \
# series id
# IEAIPIN    US Incurrence of Portfolio Investment Liabilities
# IEASAD                       Seasonal Adjustment Discrepancy
# IEASD                                Statistical discrepancy
# IEASDA                               Statistical discrepancy
# IEASDN                               Statistical discrepancy
#
#           observation_start observation_end  frequency frequency_short  \
# series id
# IEAIPIN          1999-01-01      2024-07-01  Quarterly               Q
# IEASAD           1999-01-01      2019-10-01  Quarterly               Q
# ...

# %%
#You must specify the series ID of the data set you are fetching
data = fred.get_series('IEAIPIN')

#Graphing the data
plt.plot(data.index, data.values)
plt.xlabel('Year')
plt.ylabel('Value ($)')
plt.title('US Incurrence of Portfolio Investment Liabilities')
plt.grid(True)
plt.show()

# %%
#Exploring U.S. Import and Export Price Indexes
data = fred.search_by_release(release_id=188)
data.tail()
# Out:
#                   id realtime_start realtime_end  \
# series id
# OTHERMANU  OTHERMANU     2024-12-19   2024-12-19
# OTHERNONM  OTHERNONM     2024-12-19   2024-12-19
# OTHERTOT    OTHERTOT     2024-12-19   2024-12-19
# PRIMTOT      PRIMTOT     2024-12-19   2024-12-19
# UKTOT          UKTOT     2024-12-19   2024-12-19
#
#                                                        title  \
# series id
# OTHERMANU  Import Price Index: Other Countries - Manufact...
# OTHERNONM  Import Price Index: Other Countries - Nonmanuf...
# OTHERTOT   Import Price Index: Other Countries - All comm...
# PRIMTOT    Import Price Index by Origin (NAICS): All Indu...
# UKTOT      Import Price Index by Origin (NAICS): All Indu...
#
#           observation_start observation_end frequency frequency_short  \
# series id
# OTHERMANU        1990-12-01      2017-12-01   Monthly               M
# OTHERNONM        1990-12-01      2017-12-01   Monthly               M
# ...

# %%
#fetching the name of the series
series_info = fred.get_series_info('UKTOT')
title = series_info['title']
print(title)
# Out:
# Import Price Index by Origin (NAICS): All Industries for United Kingdom

# %%
#You must specify the series ID of the data set you are fetching
data = fred.get_series('UKTOT')

#Graphing the data
plt.plot(data.index, data.values)
plt.xlabel('Year')
plt.ylabel('Index')
plt.title('Import Price Index by Origin (NAICS): All Industries for United Kingdom')
plt.grid(True)
plt.show()

# %%
#Exploring Monthly Housing Affordability Index
data = fred.search_by_release(release_id=236)
data.tail()
# Out:
#                 id realtime_start realtime_end  \
# series id
# COMPHAI    COMPHAI     2024-12-19   2024-12-19
# FIXHAI      FIXHAI     2024-12-19   2024-12-19
#
#                                                        title  \
# series id
# COMPHAI    Housing Affordability Index (Composite) (DISCO...
# FIXHAI                   Housing Affordability Index (Fixed)
#
#           observation_start observation_end frequency frequency_short  units  \
# series id
# COMPHAI          2018-04-01      2019-04-01   Monthly               M  Index
# FIXHAI           2023-10-01      2024-10-01   Monthly               M  Index
#
#           units_short      seasonal_adjustment seasonal_adjustment_short  \
# series id
# COMPHAI         Index  Not Seasonally Adjusted                       NSA
# FIXHAI          Index  Not Seasonally Adjusted                       NSA
#
#                         last_updated popularity  \
# series id
# COMPHAI    2019-06-14 12:54:04-05:00         33
# ...

# %%
#You must specify the series ID of the data set you are fetching
data = fred.get_series('FIXHAI')

#Graphing the data
plt.plot(data.index, data.values)
plt.xlabel('Year')
plt.ylabel('Index')
plt.title('Housing Affordability Index (Fixed)')
plt.grid(True)
plt.show()

# %%
#Exploring Gross Domestic Product
data = fred.search_by_release(release_id=53)
data.tail()
# Out:
#                               id realtime_start realtime_end  \
# series id
# Y912RC1A027NBEA  Y912RC1A027NBEA     2024-12-19   2024-12-19
# Y934RC1A027NBEA  Y934RC1A027NBEA     2024-12-19   2024-12-19
# Y955RC1A027NBEA  Y955RC1A027NBEA     2024-12-19   2024-12-19
# YC001176Q              YC001176Q     2024-12-19   2024-12-19
# YC001177Q              YC001177Q     2024-12-19   2024-12-19
#
#                                                              title  \
# series id
# Y912RC1A027NBEA  Defined Contribution Pension Plans: Current re...
# Y934RC1A027NBEA  Defined Contribution Pension Plans: Current re...
# Y955RC1A027NBEA  Defined Contribution Pension Plans: Current re...
# YC001176Q        Personal Consumption Expenditures Excluding Fo...
# YC001177Q        Personal Consumption Expenditures: Services Ex...
#
#                 observation_start observation_end  frequency frequency_short  \
# series id
# Y912RC1A027NBEA        1987-01-01      2023-01-01     Annual               A
# ...

# %%
#fetching the name of the series
series_info = fred.get_series_info('Y912RC1A027NBEA')
title = series_info['title']
print(title)
# Out:
# Defined Contribution Pension Plans: Current receipts: Contributions: Claims to benefits: Actual employer contributions: Federal government plans

# %%
#You must specify the series ID of the data set you are fetching
data = fred.get_series('Y912RC1A027NBEA')

#Graphing the data
plt.plot(data.index, data.values)
plt.xlabel('Year')
plt.ylabel('Index')
plt.title('Defined Contribution Pension Plans: Current receipts: Contributions: Claims to benefits: Actual employer contributions: Federal government plans')
plt.grid(True)
plt.show()

# %%
#Exploring U.S. Department of Commerce: Bureau of Economic Analysis
data = fred.search('bea')
data.tail()
# Out:
#                                     id realtime_start realtime_end  \
# series id
# SESTADMINWASTRQGSP  SESTADMINWASTRQGSP     2024-12-19   2024-12-19
# SESTADMINWASTQGSP    SESTADMINWASTQGSP     2024-12-19   2024-12-19
# SESTADMINWASTQQGSP  SESTADMINWASTQQGSP     2024-12-19   2024-12-19
# RKMTADMINWASTQGSP    RKMTADMINWASTQGSP     2024-12-19   2024-12-19
# RKMTADMINWASTQQGSP  RKMTADMINWASTQQGSP     2024-12-19   2024-12-19
#
#                                                                 title  \
# series id
# SESTADMINWASTRQGSP  Real Gross Domestic Product: Administrative an...
# SESTADMINWASTQGSP   Chain-Type Quantity Index for Real GDP: Admini...
# SESTADMINWASTQQGSP  Chain-Type Quantity Index for Real GDP: Admini...
# RKMTADMINWASTQGSP   Chain-Type Quantity Index for Real GDP: Admini...
# RKMTADMINWASTQQGSP  Chain-Type Quantity Index for Real GDP: Admini...
#
#                    observation_start observation_end  frequency  \
# series id
# ...

# %%
#fetching the name of the series
series_info = fred.get_series_info('SESTADMINWASTRQGSP')
title = series_info['title']
print(title)
# Out:
# Real Gross Domestic Product: Administrative and Support and Waste Management and Remediation Services (56) in the Southeast BEA Region

# %%
#You must specify the series ID of the data set you are fetching
data = fred.get_series('SESTADMINWASTRQGSP')

#Graphing the data
plt.plot(data.index, data.values)
plt.xlabel('Year')
plt.ylabel('Index')
plt.title('Real Gross Domestic Product: Administrative and Support and Waste Management and Remediation Services (56) in the Southeast BEA Region')
plt.grid(True)
plt.show()

# %%
#Exploring United States of America
data = fred.search('usa')
data.tail()
# Out:
#                           id realtime_start realtime_end  \
# series id
# CEU1021100001  CEU1021100001     2024-12-19   2024-12-19
# CUUS0000SAH      CUUS0000SAH     2024-12-19   2024-12-19
# CEU6500000001  CEU6500000001     2024-12-19   2024-12-19
# CEU4300000001  CEU4300000001     2024-12-19   2024-12-19
# WPS0571              WPS0571     2024-12-19   2024-12-19
#
#                                                            title  \
# series id
# CEU1021100001              All Employees, Oil and Gas Extraction
# CUUS0000SAH    Consumer Price Index for All Urban Consumers: ...
# CEU6500000001  All Employees, Private Education and Health Se...
# CEU4300000001      All Employees, Transportation and Warehousing
# WPS0571        Producer Price Index by Commodity: Fuels and R...
#
#               observation_start observation_end   frequency frequency_short  \
# series id
# CEU1021100001        1972-01-01      2024-11-01     Monthly               M
# ...

# %%
#You must specify the series ID of the data set you are fetching
data = fred.get_series('CEU1021100001')

#Graphing the data
plt.plot(data.index, data.values)
plt.xlabel('Year')
plt.ylabel('Thousands of Employees')
plt.title('All Employees, Oil and Gas Extraction')
plt.grid(True)
plt.show()

# %%
#Exploring U.S. International Trade in Goods and Services
data = fred.search_by_category(category_id=51)
data.tail()
# Out:
#                               id realtime_start realtime_end  \
# series id
# H1RIFSPABM03NB    H1RIFSPABM03NB     2024-12-19   2024-12-19
# H1RIFSPABM03NM    H1RIFSPABM03NM     2024-12-19   2024-12-19
# H1RIFSPABM03NWF  H1RIFSPABM03NWF     2024-12-19   2024-12-19
# WBA3M                      WBA3M     2024-12-19   2024-12-19
# WBA6M                      WBA6M     2024-12-19   2024-12-19
#
#                                                              title  \
# series id
# H1RIFSPABM03NB   Average Dealer Offering Rate on 3-Month Domest...
# H1RIFSPABM03NM   Average Dealer Offering Rate on 3-Month Domest...
# H1RIFSPABM03NWF  Average Dealer Offering Rate on 3-Month Domest...
# WBA3M               3-Month Bankers Acceptance Rate (DISCONTINUED)
# WBA6M            Average Dealer Offering Rate on 6-Month Domest...
#
#                 observation_start observation_end              frequency  \
# series id
# H1RIFSPABM03NB         1965-02-04      2000-06-30                  Daily
# ...

# %%
#fetching the name of the series
series_info = fred.get_series_info('H1RIFSPABM03NB')
title = series_info['title']
print(title)
# Out:
# Average Dealer Offering Rate on 3-Month Domestic Private Bankers' Acceptances, Quoted on a Discount Basis (DISCONTINUED)

# %%
#You must specify the series ID of the data set you are fetching
data = fred.get_series('H1RIFSPABM03NB')

#Graphing the data
plt.plot(data.index, data.values)
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.title('Average Dealer Offering Rate on 3-Month Domestic Private Bankers Acceptances, Quoted on a Discount Basis (DISCONTINUED)')
plt.grid(True)
plt.show()

# %%
#Exploring Advance Monthly Sales for Retail and Food Services
data = fred.search_by_category(category_id=9)
data.tail()
# Out:
#                                           id realtime_start realtime_end  \
# series id
# SUUR0000SA0                      SUUR0000SA0     2024-12-19   2024-12-19
# TRMMEANCPIM094SFRBCLE  TRMMEANCPIM094SFRBCLE     2024-12-19   2024-12-19
# TRMMEANCPIM157SFRBCLE  TRMMEANCPIM157SFRBCLE     2024-12-19   2024-12-19
# TRMMEANCPIM158SFRBCLE  TRMMEANCPIM158SFRBCLE     2024-12-19   2024-12-19
# TRMMEANCPIM159SFRBCLE  TRMMEANCPIM159SFRBCLE     2024-12-19   2024-12-19
#
#                                                                    title  \
# series id
# SUUR0000SA0            Chained Consumer Price Index for All Urban Con...
# TRMMEANCPIM094SFRBCLE              16% Trimmed-Mean Consumer Price Index
# TRMMEANCPIM157SFRBCLE              16% Trimmed-Mean Consumer Price Index
# TRMMEANCPIM158SFRBCLE              16% Trimmed-Mean Consumer Price Index
# TRMMEANCPIM159SFRBCLE              16% Trimmed-Mean Consumer Price Index
#
# ...

# %%
#fetching the name of the series
series_info = fred.get_series_info('SUUR0000SA0')
title = series_info['title']
print(title)
# Out:
# Chained Consumer Price Index for All Urban Consumers: All Items in U.S. City Average

# %%
#You must specify the series ID of the data set you are fetching
data = fred.get_series('SUUR0000SA0')

#Graphing the data
plt.plot(data.index, data.values)
plt.xlabel('Year')
plt.ylabel('Index')
plt.title('Chained Consumer Price Index for All Urban Consumers: All Items in U.S. City Average')
plt.grid(True)
plt.show()
